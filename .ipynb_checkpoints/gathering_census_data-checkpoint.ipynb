# %%
import pandas as pd
import requests
from census import Census

from config import api_key

c = Census(api_key, year=2017)
print(api_key)
# Out:
# 85ac64b6b5a9c0901b00329d1ef41f0c53ccfc98

# %%
census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E","B23025_002E","B25058_001E","B08301_001E","B08301_003E","B08301_010E","B15003_002E","B15003_018E","B15003_017E",
                          "B15003_022E","B15003_021E","B15003_023E","B15003_024E","B15003_025E","B08101_041E",
                          "B17001_002E"), geo={'for': 'tract:*','in': 'state:17 county:031'})

census_pd = pd.DataFrame(census_data)

census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      'B23025_002E': "Employed Population",
                                      "B25058_001E": "Median Contract Rent",
                                      "B08301_001E": "Means of transport",
                                      'B08301_003E': "Means of transport (Auto)",
                                      "B08301_010E": "Means of transport (Public)",
                                      "B08101_041E": "Means of transport (Other)",
                                      "B15003_002E": "No Education",
                                      "B15003_017E": "High School",
                                      "B15003_018E": "GED",
                                      "B15003_022E": "Bachelors",
                                      "B15003_021E": "Some College",
                                      "B15003_023E": "Masters",
                                      "B15003_024E": "Professional",
                                      "B15003_025E": "Doctorate",
                                      "NAME": "Name"})
print(len(census_pd))
census_pd.head()
# Out:
# 1319
#    Median Age  Population  Means of transport (Other)  Means of transport  \
# 0        44.0      5541.0                        30.0              2878.0
# 1        33.0      1600.0                        17.0               790.0
# 2        28.0      6464.0                        13.0              2892.0
# 3        29.9      2307.0                         4.0               800.0
# 4        29.9      3298.0                         0.0              1289.0
#
#    Means of transport (Auto)  Means of transport (Public)  No Education  \
# 0                     2232.0                        366.0           0.0
# 1                      357.0                        188.0           4.0
# 2                     1469.0                        431.0         327.0
# 3                      448.0                        185.0          13.0
# 4                      545.0                        291.0         115.0
#
#    High School    GED  Some College   ...    Doctorate  Poverty Count  \
# ...

# %%
census_pd.to_csv('../analysis_data/census_data.csv')
