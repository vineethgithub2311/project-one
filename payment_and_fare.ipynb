# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.DataFrame(
    pd.read_csv(
        '../analysis_data/pay_and_fare.csv',
    usecols=['Fare','Payment Type'],
    dtype={
        'Fare':float,
        'Payment Type':object
    }))
df.head()
# Out:
#     Fare Payment Type
# 0  11.45         Cash
# 1   4.75         Cash
# 2   5.65  Credit Card
# 3   5.45         Cash
# 4   6.75         Cash

# %%
df=df['Fare'].loc[df['Fare']>1]

# %%
df=df1['Fare'].loc[df1['Fare']<300]

# %%
plt.figure(num=None, figsize=(10, 10), dpi=80, facecolor='w', edgecolor='k')
plt.hist(df2, bins=100,
     range=(0,80), rwidth=0.9,
     label=None)
plt.xlabel('Fare')
plt.ylabel('Number of Trips')
plt.title('Distribution of Fares')
plt.savefig('output/fare_distibution.png')

# %%
plt.figure(num=None, figsize=(10, 10), dpi=80, facecolor='w', edgecolor='k')
plt.hist(df2, bins=100, density=True,
     range=(0,80), rwidth=0.9,
     label=None)
plt.xlabel('Fare')
plt.ylabel('Fractional Share')
plt.title('Distribution of Fares')
plt.savefig('output/fare_distibution1.png')

# %%
bins=[0,10,20,30,40,50,60]
labels=['less_10','ten_twenty','twenty_thirty','thrity_forty','forty_fifty','more_50']
df['Bins']=pd.cut(df['Fare'],bins=bins,labels=labels)
df.head()
# Out:
#     Fare Payment Type        Bins
# 0  11.45         Cash  ten_twenty
# 1   4.75         Cash     less_10
# 2   5.65  Credit Card     less_10
# 3   5.45         Cash     less_10
# 4   6.75         Cash     less_10

# %%
gb=df.groupby(['Payment Type','Bins'])
df1=gb['Fare'].count().reset_index()

# %%
total=df1['Fare'].loc[df1['Bins']==labels[0]].sum()
less_10=df1.loc[df1['Bins']==labels[0]]
less_10['Percent']=less_10['Fare']/total*100

total=df1['Fare'].loc[df1['Bins']==labels[1]].sum()
ten_twenty=df1.loc[df1['Bins']==labels[1]]
ten_twenty['Percent']=ten_twenty['Fare']/total*100

total=df1['Fare'].loc[df1['Bins']==labels[2]].sum()
twenty_thirty=df1.loc[df1['Bins']==labels[2]]
twenty_thirty['Percent']=twenty_thirty['Fare']/total*100

total=df1['Fare'].loc[df1['Bins']==labels[3]].sum()
thirty_forty=df1.loc[df1['Bins']==labels[3]]
thirty_forty['Percent']=thirty_forty['Fare']/total*100

total=df1['Fare'].loc[df1['Bins']==labels[4]].sum()
forty_fifty=df1.loc[df1['Bins']==labels[4]]
forty_fifty['Percent']=forty_fifty['Fare']/total*100

total=df1['Fare'].loc[df1['Bins']==labels[5]].sum()
more_50=df1.loc[df1['Bins']==labels[5]]
more_50['Percent']=more_50['Fare']/total*100

# empty_df=pd.DataFrame()

# for label in labels:
#     total=df1['Fare'].loc[df1['Bins']==label].sum()
#     df2=df1.loc[df1['Bins']==label]
#     df2['Percent']=df2['Fare']/total*100
#     pd.concat([empty_df,df2])
# Out:
# C:\Users\nilay\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
less_10['Percent'].values[0:2]
# Out:
# array([69.91210608, 29.33120572])

# %%
pie_labels=['Cash','Credit Card']
explode=[0.1,0]

plt.figure(figsize=(10,10))
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3)



ax1.pie(less_10['Percent'].values[0:2],explode=explode,autopct="%1.1f%%",
       labels=pie_labels,shadow=True,startangle=120)

ax2.pie(ten_twenty['Percent'].values[0:2],explode=explode,autopct="%1.1f%%",
       labels=pie_labels,shadow=True,startangle=120)

ax3.pie(twenty_thirty['Percent'].values[0:2],explode=explode,autopct="%1.1f%%",
       labels=pie_labels,shadow=True,startangle=120)

ax4.pie(thirty_forty['Percent'].values[0:2],explode=explode,autopct="%1.1f%%",
       labels=pie_labels,shadow=True,startangle=120)

ax5.pie(forty_fifty['Percent'].values[0:2],explode=explode,autopct="%1.1f%%",
       labels=pie_labels,shadow=True,startangle=120,radius=1)

ax6.pie(more_50['Percent'].values[0:2],explode=explode,autopct="%1.1f%%",
       labels=pie_labels,shadow=True,startangle=120,radius=1)

ax1.set_title('Less than $10')
ax2.set_title('Between \$10 and \$20')
ax3.set_title('Between \$20 and \$30')
ax4.set_title('Between \$30 and \$40')
ax5.set_title('Between \$40 and \$50')
ax6.set_title('More than $50')

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
fig.savefig('test2png.png', dpi=100)
plt.savefig('output/usage.png')

# %%
help(figsize)
# Out:
# Help on tuple object:
#
# class tuple(object)
#  |  tuple(iterable=(), /)
#  |
#  |  Built-in immutable sequence.
#  |
#  |  If no argument is given, the constructor returns an empty tuple.
#  |  If iterable is specified the tuple is initialized from iterable's items.
#  |
#  |  If the argument is a tuple, the return value is the same object.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __iter__(self, /)
# ...
