# %%
import pandas as pd
from sodapy import Socrata

app_token='hIX2gB8mcj40sF80ML4xw2qzC'

client = Socrata("data.cityofchicago.org", app_token)

#'5eg2-c264' is the cta bus boardings dataset, and we set the limit to the number of rows of data we want

results = client.get("5eg2-c264", limit=100000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %%
results_df
# Out:
#       alightings boardings         cross_street  daytype  \
# 0          150.0     183.4               AUSTIN  Weekday
# 1            0.2       5.3  MAYFIELD (EXTENDED)  Weekday
# 2            0.7       8.3               MENARD  Weekday
# 3            3.0      17.9            5700 WEST  Weekday
# 4           11.2      74.0                LOTUS  Weekday
# 5            2.5      14.3            5351 WEST  Weekday
# 6           14.1      62.4             LOCKWOOD  Weekday
# 7            0.0       0.1              LARAMIE  Weekday
# 8            0.0       0.0             LAVERGNE  Weekday
# 9            0.0       0.0            4849 WEST  Weekday
# 10         145.2     530.5               CICERO  Weekday
# 11          13.1      51.6           KILPATRICK  Weekday
# 12           8.1      16.2               KENTON  Weekday
# 13           5.2      17.9               KOLMAR  Weekday
# 14          29.6      56.4             KILBOURN  Weekday
# ...

# %%
new_df=results_df[['stop_id','alightings','boardings','location']]

# %%
new_df.to_csv('data/cta_geoloc.csv')
